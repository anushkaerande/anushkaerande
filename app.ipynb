# %%
pip install flask
# Out:
# Requirement already satisfied: flask in d:\anacon\lib\site-packages (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in d:\anacon\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in d:\anacon\lib\site-packages (from flask) (2.0.3)
# Requirement already satisfied: click>=5.1 in d:\anacon\lib\site-packages (from flask) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in d:\anacon\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: colorama in d:\anacon\lib\site-packages (from click>=5.1->flask) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anacon\lib\site-packages (from Jinja2>=2.10.1->flask) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cikit-learn (d:\anacon\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\anacon\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\anacon\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\anacon\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\anacon\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (d:\anacon\lib\site-packages)

# %%
from __future__ import division, print_function #import all required libraries
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from flask import Flask, request, render_template
from werkzeug.utils import secure_filename
import statistics as st

app = Flask(__name__)  #create the app using flask

@app.route("/")
def home():
    return render_template("index1.html")
    
    
@app.route('/camera', methods = ['GET', 'POST'])
def camera():
    i=0

    GR_dict={0:(0,255,0),1:(0,0,255)}
    model = tf.keras.models.load_model('final_model1.h5')
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    output=[]
    cap = cv2.VideoCapture(0)
    while (i<=30):
        ret, img = cap.read()
        faces = face_cascade.detectMultiScale(img,1.05,5)

        for x,y,w,h in faces:

            face_img = img[y:y+h,x:x+w] 

            resized = cv2.resize(face_img,(224,224))
            reshaped=resized.reshape(1, 224,224,3)/255
            predictions = model.predict(reshaped)

            max_index = np.argmax(predictions[0])

            emotions = ('angry', 'fear', 'happy', 'sad', 'neutral', 'surprise')
            predicted_emotion = emotions[max_index]
            output.append(predicted_emotion)
            
            
            
            cv2.rectangle(img,(x,y),(x+w,y+h),GR_dict[1],2)
            cv2.rectangle(img,(x,y-40),(x+w,y),GR_dict[1],-1)
            cv2.putText(img, predicted_emotion, (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        i = i+1

        cv2.imshow('LIVE', img)
        key = cv2.waitKey(1)
        if key == 27: 
            cap.release()
            cv2.destroyAllWindows()
            break
    print(output)
    cap.release()
    cv2.destroyAllWindows()
    final_output1 = st.mode(output)
    return render_template("buttons.html",final_output=final_output1)


@app.route('/templates/buttons', methods = ['GET','POST'])
def buttons():
    return render_template("buttons.html")

@app.route('/movies/surprise', methods = ['GET', 'POST'])
def moviesSurprise():
    return render_template("moviesSurprise.html")

@app.route('/movies/angry', methods = ['GET', 'POST'])
def moviesAngry():
    return render_template("moviesAngry.html")

@app.route('/movies/sad', methods = ['GET', 'POST'])
def moviesSad():
    return render_template("moviesSad.html")

@app.route('/movies/happy', methods = ['GET', 'POST'])
def moviesHappy():
    return render_template("moviesHappy.html")

@app.route('/movies/fear', methods = ['GET', 'POST'])
def moviesFear():
    return render_template("moviesFear.html")

@app.route('/movies/neutral', methods = ['GET', 'POST'])
def moviesNeutral():
    return render_template("moviesNeutral.html")

@app.route('/songs/surprise', methods = ['GET', 'POST'])
def songsSurprise():
    return render_template("songsSurprise.html")

@app.route('/songs/angry', methods = ['GET', 'POST'])
def songsAngry():
    return render_template("songsAngry.html")

@app.route('/songs/sad', methods = ['GET', 'POST'])
def songsSad():
    return render_template("songsSad.html")

@app.route('/songs/happy', methods = ['GET', 'POST'])
def songsHappy():
    return render_template("songsHappy.html")

@app.route('/songs/fear', methods = ['GET', 'POST'])
def songsFear():
    return render_template("songsFear.html")

@app.route('/songs/neutral', methods = ['GET', 'POST'])

def songsNeutral():
    return render_template("songsNeutral.html")

    
if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [27/May/2022 23:56:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:56:36] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# ['neutral', 'neutral', 'sad', 'sad', 'sad', 'happy', 'happy', 'happy', 'happy', 'happy']
# 127.0.0.1 - - [27/May/2022 23:56:49] "GET /camera HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:56:49] "GET /static/button_style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:49] "GET /static/images.jpeg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:50] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2022 23:56:51] "GET /movies/happy HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg7.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg8.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg9.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg10.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg11.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg12.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /movies/static/img12.png HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/%20movies/happyimg1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg4.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg5.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [27/May/2022 23:56:52] "GET /static/happy%20movies/happyimg6.jpg HTTP/1.1" 304 -
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# ['sad', 'sad', 'happy', 'neutral', 'happy', 'sad', 'happy', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# 127.0.0.1 - - [27/May/2022 23:57:09] "GET /camera HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /movies/neutral HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg11.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg8.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg12.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg7.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg9.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg10.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /movies/static/img12.png HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg3.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg4.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:13] "GET /static/Neutral_Movies/neutralimg5.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:14] "GET /static/Neutral_Movies/neutralimg6.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:20] "GET /songs/neutral HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:20] "GET /static/Neutral_Songs/neutralsongimg1.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:20] "GET /static/img9.png HTTP/1.1" 404 -
# 127.0.0.1 - - [27/May/2022 23:57:20] "GET /static/Neutral_Songs/neutralsongimg10.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg11.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg9.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg12.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg8.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg3.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg4.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg5.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg7.jfif HTTP/1.1" 200 -
# 127.0.0.1 - - [27/May/2022 23:57:21] "GET /static/Neutral_Songs/neutralsongimg6.jfif HTTP/1.1" 200 -
